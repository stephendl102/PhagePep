# %%
# %load_ext autoreload
# %autoreload 2

import os
# Run everything on CPU, if GPU is available comment out
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""


import sys
sys.path.append("src/")
import src.preprocessing.data_loading as data_loading
import models.experiment as experiment
import models.rnn as rnn
import numpy as np
from tensorflow import keras
from functools import partial

from analysis.hit_rate_analysis import (
    plot_ratio_by_ranking,
    seq_contains_mdm2_motif,
    seq_contains_12ca5_motif,
    benchmark_cross_validated_hit_rate,
)
from analysis.scatter_plots import (
    plot_fancy_hexbin_relations
)
from models.rnn import multi_channel_mse
# Out:
# Generating ER datafiles!

# %%
protein_of_interest = "MDM2"
other_protein = "12ca5"

def proxy_ranking_lambda(x):
    # Proxy metric is defined as FC (y_raw[:, 1]) + ER (y_raw[:, 2])
    return x[1] + x[2]

top_k_size = 500 if protein_of_interest == "MDM2" else 1000
motif_dectection_func = (
    seq_contains_mdm2_motif
    if protein_of_interest == "MDM2"
    else seq_contains_12ca5_motif
)
model_save_name = (
    "trained_models/final_models/mdm2_modelSL.h5"
    if protein_of_interest == "MDM2"
    else "trained_models/final_models/12ca5_model.h5"
)


X, y_raw, peptides, FEATURE_LIST = data_loading.build_joint_dataset(
    er_datafile=f"{protein_of_interest}_merged_ER.csv",
    volcano_datafile="12ca5-MDM2-R3.csv",
    protein_of_interest=protein_of_interest,
    other_protein=other_protein,
)
print(FEATURE_LIST)
print(peptides[0:5])
# Out:
# ['Pro2Vec', 'RAA', 'H11', 'H12', 'H2', 'NCI', 'P11', 'P12', 'P2', 'SASA', 'V', 'F', 'A1', 'E', 'T', 'A2', 'A_one_hot', 'R_one_hot', 'N_one_hot', 'D_one_hot', 'C_one_hot', 'Q_one_hot', 'E_one_hot', 'G_one_hot', 'H_one_hot', 'I_one_hot', 'L_one_hot', 'K_one_hot', 'M_one_hot', 'F_one_hot', 'P_one_hot', 'S_one_hot', 'T_one_hot', 'W_one_hot', 'Y_one_hot', 'V_one_hot', 'X_one_hot']
# ['ILTQTSA', 'AGCGYVCNR', 'AVCRQTYPC', 'AQCRWGYCN', 'AMCSDTLCQ']
# /Users/stephen/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:618: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, axis=axis, **kwds)

# %% [markdown]
# ## Baseline Experimental Rankings

# %%
volcano_ordering = (
    np.array([(val[0] + 6) * val[1] if val[1] > 0 else 0 for val in y_raw])
    if protein_of_interest == "MDM2"
    else np.array([val[0] * val[1] for val in y_raw])
)
plot_fancy_hexbin_relations(
    1,
    0,
    datapoints=y_raw,
    ordering=volcano_ordering,
    all_positives=None,
    line_color='#5757F9',
    top_k=top_k_size,
)

fc_alone_mdm2_ordering = [y[1] for y in y_raw]
plot_fancy_hexbin_relations(
    1,
    0,
    datapoints=y_raw,
    ordering=fc_alone_mdm2_ordering,
    all_positives=None,
    line_color='#56B4E9',
    top_k=top_k_size,
)

er_mdm2_ordering = [y[2] for y in y_raw]

plot_fancy_hexbin_relations(
    2,
    1,
    datapoints=y_raw,
    ordering=er_mdm2_ordering,
    all_positives=None,
    line_color='#D55E00',
    title='Ordered by ER Alone',
    top_k=top_k_size,
)

er_fc_joint_mdm2_ordering = [y[2] + y[1] for y in y_raw]
plot_fancy_hexbin_relations(
    2,
    1,
    datapoints=y_raw,
    ordering=er_fc_joint_mdm2_ordering,
    all_positives=None,
    line_color='#0F980F',
    title='Ordered by ER + FC',
    top_k=top_k_size,
)

print(fc_alone_mdm2_ordering[:10])
# Out:
# extent (-11.26699745539576, 12.802835987110129, -0.8329379238887278, 27.369964117469774)
# extent (-11.26699745539576, 12.802835987110129, -0.8329379238887278, 27.369964117469774)
# extent (-12.424972942105276, 18.0343835663439, -11.26699745539576, 12.802835987110129)
# extent (-12.424972942105276, 18.0343835663439, -11.26699745539576, 12.802835987110129)
# [2.1972245773362196, -5.978885764901122, 3.6635616461296463, 4.7535901911063645, 4.204692619390966, 4.5217885770490405, 3.7376696182833684, 1.9459101490553132, 5.616771097666572, -5.802118375377063]

# %%
sorted_peptides = [p for _, p in sorted(zip(fc_alone_mdm2_ordering, peptides), reverse=True)]
print(sorted_peptides[:10])

# %%
['ACKTFMCWW', 'AFCDWFWCS', 'ASCFANTCF', 'WSLGYTG', 'ACSTFECFW', 'AFCDWFECN', 'KVVLLAR', 'AFCDLFWCD', 'ACTTFECWW', 'ACNHKIWCL']

# %%
import analysis.heatmap_analysis_SDL as heatmap


def show_heatmap_for_top_k(title, ordering, color, peptides=peptides, top_k=top_k_size):
    top_k_mask = ordering >= np.partition(ordering, kth=-top_k)[-top_k]
    top_k_peptides = [pep for pep, mask in zip(peptides, top_k_mask) if mask]

    heatmap.generate_heatmap(
        top_k_peptides, 
        title=title,
        vmax=100 if protein_of_interest == 'MDM2' else 600,
        colormap=color,
    )

show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC Ranking", fc_alone_mdm2_ordering, 'Blues')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC + P-value Ranking", volcano_ordering, 'Purples')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER Ranking", er_mdm2_ordering, 'Oranges')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER + FC Ranking", er_fc_joint_mdm2_ordering, 'Greens')
# Out:
# max is  1
# max is  1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 17
#      15 show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC Ranking", fc_alone_mdm2_ordering, 'Blues')
#      16 show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC + P-value Ranking", volcano_ordering, 'Purples')
# ---> 17 show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER Ranking", er_mdm2_ordering, 'Oranges')
#      18 show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER + FC Ranking", er_fc_joint_mdm2_ordering, 'Greens')
#
# Cell In[4], line 8, in show_heatmap_for_top_k(title, ordering, color, peptides, top_k)
#       5 top_k_mask = ordering >= np.partition(ordering, kth=-top_k)[-top_k]
#       6 top_k_peptides = [pep for pep, mask in zip(peptides, top_k_mask) if mask]
# ----> 8 heatmap.generate_heatmap(
#       9     top_k_peptides,
#      10     title=title,
#      11     vmax=100 if protein_of_interest == 'MDM2' else 600,
#      12     colormap=color,
#      13 )
#
# File ~/Desktop/PythonPhastPep/2_29_24/RatmirData/ml_phage_display-main/src/analysis/heatmap_analysis_SDL.py:33, in generate_heatmap(seqs, nmer_len, title, vmax, vmin, drop_C, colormap)
#      31 frames = []
#      32 for i in range(nmer_len):
# ---> 33     counts = seq_df.iloc[:, i].value_counts()
#      34     counts = counts.reindex(aa_index, fill_value=0)
#      35     frames.append(counts)
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/pandas/core/indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/pandas/core/indexing.py:1466, in _iLocIndexer._validate_key(self, key, axis)
#    1464     return
#    1465 elif is_integer(key):
# -> 1466     self._validate_integer(key, axis)
#    1467 elif isinstance(key, tuple):
#    1468     # a tuple should already have been caught by this point
#    1469     # so don't treat a tuple as a valid indexer
#    1470     raise IndexingError("Too many indexers")
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/pandas/core/indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ## BiLSTM Ranking

# %%
cross_validation_results = experiment.Experiment().run_cross_validation_experiment(
    X=X,
    y=y_raw,
    model_architecture=partial(
        rnn.ThreeChannelRegressionRNN_gelu, depth=7, loss=multi_channel_mse, width=141
    ),
    optimizer=partial(
        keras.optimizers.Adam, learning_rate=0.0005, weight_decay=0.5
    ),
    n_splits=10,
    load_trained_model=True,
    model_save_name=model_save_name,
    normalize=True,
    batch_size=128,
    num_epochs=6,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cross_validation_results = experiment.Experiment().run_cross_validation_experiment(
#       2     X=X,
#       3     y=y_raw,
#       4     model_architecture=partial(
#       5         rnn.ThreeChannelRegressionRNN_gelu, depth=7, loss=multi_channel_mse, width=141
#       6     ),
#       7     optimizer=partial(
#       8         keras.optimizers.Adam, learning_rate=0.0005, weight_decay=0.5
#       9     ),
#      10     n_splits=10,
#      11     load_trained_model=True,
#      12     model_save_name=model_save_name,
#      13     normalize=True,
#      14     batch_size=128,
#      15     num_epochs=6,
#      16 )
#
# File ~/Desktop/PythonPhastPep/2_29_24/RatmirData/ml_phage_display-main/src/models/experiment.py:122, in Experiment.run_cross_validation_experiment(self, X, y, model_architecture, optimizer, n_splits, load_trained_model, model_save_name, normalize, batch_size, num_epochs)
#     111     y_test_scaled = yscaler.transform(y_test)
#     112 model = self.train(
#     113     X_train,
#     114     y_train_scaled,
#    (...)
#     120     model_save_name=model_save_name + str(split_idx),
#     121 )
# --> 122 y_pred, metrics = self.predict(model, X_test, y_test_scaled)
#     123 y_pred_rescaled = yscaler.inverse_transform(y_pred) if normalize else None
#     124 results.append(
#     125     Result(
#     126         trained_model=model,
#    (...)
#     133     )
#     134 )
#
# File ~/Desktop/PythonPhastPep/2_29_24/RatmirData/ml_phage_display-main/src/models/experiment.py:219, in Experiment.predict(self, model, X_test, y_true)
#     217 def predict(self, model, X_test, y_true):
#     218     if isinstance(model, keras.models.Sequential):
# --> 219         y_pred = model(X_test)
#     220     else:
#     221         y_pred = model.predict(X_test.reshape(X_test.shape[0], -1))
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/mambaforge/envs/BiLSTM_new/lib/python3.10/site-packages/keras/engine/input_spec.py:295, in assert_input_compatibility(input_spec, inputs, layer_name)
#     293 if spec_dim is not None and dim is not None:
#     294     if spec_dim != dim:
# --> 295         raise ValueError(
#     296             f'Input {input_index} of layer "{layer_name}" is '
#     297             "incompatible with the layer: "
#     298             f"expected shape={spec.shape}, "
#     299             f"found shape={display_shape(x.shape)}"
#     300         )
#
# ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 12, 37), found shape=(3292, 14, 37)

# %%
bilstm_ordering, y_pred = benchmark_cross_validated_hit_rate(
    cross_validation_results=cross_validation_results,
    y_raw=y_raw,
    peptides=peptides,
    proxy_ranking_lambda=proxy_ranking_lambda,
    top_k_size=top_k_size,
    motif_dectection_func=motif_dectection_func,
)

# %%
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by BiLSTM Ranking", bilstm_ordering, 'Reds')

# %% [markdown]
# ## Benchmark

# %%
rankings=[
(
    bilstm_ordering, 'BiLSTM Model Ranking', '#F94040'
),
(
    er_mdm2_ordering, 'ER Ranking', '#D55E00'
),
(
    er_fc_joint_mdm2_ordering, 'Joint ER/FC Ranking', '#0F980F'
),
(
    volcano_ordering, 'Joint FC/Pval Ranking', '#5757F9'
),
(
    fc_alone_mdm2_ordering, 'FC Ranking', '#56B4E9'
),
]
print(fc_alone_mdm2_ordering[:10])

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 12), dpi=80)

# %%
plot_ratio_by_ranking(
    peptides=peptides,
    y_rankings=rankings,
    title="",
    peptide_dataset_size=top_k_size,
    hit_rate_func=seq_contains_mdm2_motif if protein_of_interest =="MDM2" else seq_contains_12ca5_motif,
    save_file='mdm2_hit_rankings.csv' if protein_of_interest =='MDM2' else '12ca5_hit_rankings.csv',
)

# %% [markdown]
# # Now Hit Rate Benchmarking for 12ca5

# %%
protein_of_interest = "12ca5"
other_protein = "MDM2"

def proxy_ranking_lambda(x):
    # Proxy metric is defined as FC (y_raw[:, 1]) + ER (y_raw[:, 2])
    return x[1] + x[2]

top_k_size = 500 if protein_of_interest == "MDM2" else 1000
motif_dectection_func = (
    seq_contains_mdm2_motif
    if protein_of_interest == "MDM2"
    else seq_contains_12ca5_motif
)
model_save_name = (
    "trained_models/final_models/mdm2_model.h5"
    if protein_of_interest == "MDM2"
    else "trained_models/final_models/12ca5_model.h5"
)


X, y_raw, peptides, FEATURE_LIST = data_loading.build_joint_dataset(
    er_datafile=f"{protein_of_interest}_merged_ER.csv",
    volcano_datafile="12ca5-MDM2-R3.csv",
    protein_of_interest=protein_of_interest,
    other_protein=other_protein,
)

# %%
volcano_ordering = (
    np.array([(val[0] + 6) * val[1] if val[1] > 0 else 0 for val in y_raw])
    if protein_of_interest == "MDM2"
    else np.array([val[0] * val[1] for val in y_raw])
)
plot_fancy_hexbin_relations(
    1,
    0,
    datapoints=y_raw,
    ordering=volcano_ordering,
    all_positives=None,
    line_color='#5757F9',
    top_k=top_k_size,
)

fc_alone_mdm2_ordering = [y[1] for y in y_raw]
plot_fancy_hexbin_relations(
    1,
    0,
    datapoints=y_raw,
    ordering=fc_alone_mdm2_ordering,
    all_positives=None,
    line_color='#56B4E9',
    top_k=top_k_size,
)

er_mdm2_ordering = [y[2] for y in y_raw]

plot_fancy_hexbin_relations(
    2,
    1,
    datapoints=y_raw,
    ordering=er_mdm2_ordering,
    all_positives=None,
    line_color='#D55E00',
    title='Ordered by ER Alone',
    top_k=top_k_size,
)

er_fc_joint_mdm2_ordering = [y[2] + y[1] for y in y_raw]
plot_fancy_hexbin_relations(
    2,
    1,
    datapoints=y_raw,
    ordering=er_fc_joint_mdm2_ordering,
    all_positives=None,
    line_color='#0F980F',
    title='Ordered by ER + FC',
    top_k=top_k_size,
)

# %%
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC Ranking", fc_alone_mdm2_ordering, 'Blues')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by FC + P-value Ranking", volcano_ordering, 'Purples')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER Ranking", er_mdm2_ordering, 'Oranges')
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by ER + FC Ranking", er_fc_joint_mdm2_ordering, 'Greens')

# %%
cross_validation_results = experiment.Experiment().run_cross_validation_experiment(
    X=X,
    y=y_raw,
    model_architecture=partial(
        rnn.ThreeChannelRegressionRNN_gelu, loss=multi_channel_mse, width=64
    ),
    optimizer=partial(
        keras.optimizers.Adam, learning_rate=0.0005, weight_decay=0.5
    ),
    n_splits=10,
    load_trained_model=True,
    model_save_name=model_save_name,
    normalize=True,
    batch_size=128,
    num_epochs=5,
)

# %%
bilstm_ordering, y_pred = benchmark_cross_validated_hit_rate(
    cross_validation_results=cross_validation_results,
    y_raw=y_raw,
    peptides=peptides,
    proxy_ranking_lambda=proxy_ranking_lambda,
    top_k_size=top_k_size,
    motif_dectection_func=motif_dectection_func,
)

# %%
show_heatmap_for_top_k(f"Heatmap of Top {top_k_size} {protein_of_interest} Putative Binders by BiLSTM Ranking", bilstm_ordering, 'Reds')

# %%
rankings=[
(
    bilstm_ordering, 'BiLSTM Model Ranking', '#F94040'
),
(
    er_mdm2_ordering, 'ER Ranking', '#D55E00'
),
(
    er_fc_joint_mdm2_ordering, 'Joint ER/FC Ranking', '#0F980F'
),
(
    volcano_ordering, 'Joint FC/Pval Ranking', '#5757F9'
),
(
    fc_alone_mdm2_ordering, 'FC Ranking', '#56B4E9'
),
]

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 12), dpi=80)

# %%
plot_ratio_by_ranking(
    peptides=peptides,
    y_rankings=rankings,
    title="",
    peptide_dataset_size=top_k_size,
    hit_rate_func=seq_contains_mdm2_motif if protein_of_interest =="MDM2" else seq_contains_12ca5_motif,
    save_file='mdm2_hit_rankings.csv' if protein_of_interest =='MDM2' else '12ca5_hit_rankings.csv',
)
